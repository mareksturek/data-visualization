# %% [markdown]
# ## Matplotlib plotting

# %% [markdown]
# ---

# %%
# Import libararies

import matplotlib.pyplot as plt
import numpy as np
from numpy.random import randint
# %matplotlib inline

# %%
# Various examples

# %%
x = np.linspace(1, 10, 20)
x
# Out:
# array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#         3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#         5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#         8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ])

# %%
y = randint(1, 50, 20)
y
# Out:
# array([43, 17, 33, 18, 43, 27, 17,  5,  5, 32,  7, 27, 45,  9, 32, 31, 23,
#        27, 36, 49])

# %%
x.size, y.size
# Out:
# (20, 20)

# %%
plt.plot(y);

# %%
y = y.cumsum()

# %%
plt.plot(y);

# %%
plt.plot(x, y);

# %%
plt.plot(x, y, color = 'r', marker = 'o');

# %%
plt.plot(x, y, color = 'g', marker = 'o', linestyle = '--');

# %%
# Labeling

plt.plot(x, y, color = 'r', marker = '*', linestyle = '--')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('This is a demo plot')
plt.show()

# %%
# Scatter, Bar, Hist, and Box Plots 

x, y
# Out:
# (array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#          3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#          5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#          8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ]),
#  array([ 43,  60,  93, 111, 154, 181, 198, 203, 208, 240, 247, 274, 319,
#         328, 360, 391, 414, 441, 477, 526]))

# %%
plt.scatter(x, y, linewidth = 2)
plt.show()

# %%
b = [10, 23, 43, 5, 66]
a = ['a', 'b', 'c', 'd', 'e']

plt.bar(a, b, width=0.9);

# %%
plt.hist(y, rwidth = 0.8, bins = 30);

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 3)]
data[1]
# Out:
# array([-0.01462228, -1.74060283,  4.48396156, -0.8487131 ,  1.28844293,
#         3.15218981, -2.27349152, -0.41127045,  4.99565218,  0.3825144 ,
#         2.69682848,  1.4003375 ,  0.36121786,  1.02292787, -1.92758922,
#        -1.49738999, -1.50223282, -3.59167188,  0.38254484,  2.28725973,
#         0.44494979,  1.96443818, -4.26076937,  0.03815126,  0.38393044,
#        -1.11744785,  2.00022798, -0.31165471,  1.87180084, -2.58807029,
#         4.57836441, -1.14364245, -1.16523552,  0.19622858,  0.09657715,
#        -1.33832326, -1.60277211,  0.8282577 ,  0.31185818, -0.21669796,
#        -2.82587759,  0.87653857, -0.16180458, -1.12069906,  3.38594707,
#         1.92372172,  0.95475527, -2.25224157,  0.55371287, -0.80457866,
#        -3.77860336,  0.3826099 ,  1.24635273,  3.50367133,  0.75178517,
#         1.76723152, -5.04803063, -0.16757571, -1.30501491, -0.36349405,
#        -0.46313295,  1.72913856, -0.50931297,  3.0680633 ,  1.78176066,
#         2.15792392, -1.32857611, -1.49510468,  0.85340256,  0.12384584,
#         0.20983041, -2.72520712,  1.20443789, -0.49862897, -3.11123527,
#         0.1109786 ,  1.61426301,  0.11089016,  2.9259092 , -0.01348099,
#         0.29459634, -1.48107947,  0.54745627,  0.27417906,  2.32312473,
#        -0.30992985,  0.12627378,  3.89458889, -2.834023  , -2.59584009,
#        -0.44890975, -1.61875684, -1.70972504,  2.51416871, -5.39387115,
#        -0.16560139,  4.43314311,  1.93358238,  0.54614953, -0.50604572])

# %%
plt.boxplot(data, vert = True, patch_artist=True)
plt.show()

# %%
# Subplot 

x
# Out:
# array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#         3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#         5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#         8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ])

# %%
y
# Out:
# array([ 43,  60,  93, 111, 154, 181, 198, 203, 208, 240, 247, 274, 319,
#        328, 360, 391, 414, 441, 477, 526])

# %%
y2 = y*x

# %%
plt.plot(x, y)
plt.plot(x, y2);

# %%
plt.subplot(1, 2, 1)
plt.plot(x, y)

plt.subplot(1, 2, 2)
plt.plot(x, y2);

# %%
plt.subplot(1, 2, 1)
plt.plot(x, y, marker = 'o', color = 'r')

plt.subplot(1, 2, 2)
plt.plot(x, y2, marker = '*', color = 'k', markersize = 10);

# %%
fig = plt.figure()
ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.1, 0.6, 0.4, 0.3])

ax1.plot(x, y, 'r')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_title('Y Plot')

ax2.plot(x, y2, 'g')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_title('Y2 Plot')
# Out:
# Text(0.5, 1.0, 'Y2 Plot')

# %%
# xlim, ylim, xticks, and yticks 

fig, ax = plt.subplots(1, 2, figsize = (12, 4))

ax[0].plot(x, y, x, y2)

ax[1].plot(x, y**2, 'k')

ax[1].set_ylim([2000, 5000])
ax[1].set_xlim([-5, 5])
# Out:
# (-5.0, 5.0)

# %%
fig, ax = plt.subplots(1, 2, figsize = (12, 4))

ax[0].plot(x, y, x, y2)
ax[0].set_xticks([1, 4, 9])

ax[1].plot(x, y**2, 'k')
ax[1].set_xticks([1, 4, 9])
ax[1].set_xticklabels([r'$\alpha$', r'$\beta$', r'$\delta$'])
plt.show()

# %%
# Pie Plot

labels = ['Frogs', 'Cats', 'Dogs', 'Lions']
sizes = [15, 30, 45, 80]

# %%
fig, ax = plt.subplots(figsize= (4, 4), dpi = 100)
explode = (0, 0.1, 0, 0)
ax.pie(sizes, labels = labels, autopct = '%1.1f%%', shadow = True,
      startangle = 90, explode = explode)

plt.show()

# %%
# Pie Plot Text Color 

fig, ax = plt.subplots(figsize= (4, 4), dpi = 100)
explode = (0, 0.1, 0, 0)

patches, texts, autotexts = ax.pie(sizes, labels = labels, autopct = '%1.1f%%', shadow = True,
      startangle = 90, explode = explode)
plt.setp(autotexts, size = 12, color = 'black')
autotexts[1].set_color('white')
plt.show()

# %%
# Nested Pie Chart 

fig, ax = plt.subplots(dpi = 100)
size = 0.3

vals = np.array([[60, 32], [35, 20], [26, 36]])
vals_sum = vals.sum(axis = 1)
vals_flat = vals.flatten()

cmap = plt.get_cmap('tab20c')
outer_colors = cmap(np.arange(3)*4)
inner_colors = cmap(np.arange(6)*3)

ax.pie(vals_sum, radius = 1, colors = outer_colors, 
       wedgeprops = dict(width = size, edgecolor = 'w'))

ax.pie(vals_flat, radius = 1-size, colors = inner_colors, 
       wedgeprops = dict(width = size, edgecolor = 'w'))

plt.show()

# %%
# Labeling a Pie Chart 

fig, ax = plt.subplots(dpi = 150)
recipe = ["375 g Flour", "75 g Suger", "250 g Butter", "300 g Berries"]

data = [float(x.split(' ')[0]) for x in recipe]
ingredients = [x.split(' ')[-1] for x in recipe]

def func(pct, vals):
    absolute = int(pct/100.*np.sum(vals))
    return "{:.1f}%\n({:d} g)".format(pct, absolute)


wedges, texts, autotexts = ax.pie(data, autopct = lambda pct: func(pct, data), textprops = dict(color = 'w'))

ax.legend(wedges, ingredients,
         title = 'Ingredients', loc = 'center left',
         bbox_to_anchor = (1, 0, 1, 1))

plt.show()

# %%
# Bar Chart on Polar Axis 

np.random.seed(0)
N = 30
theta = np.linspace(0.0, 2*np.pi, N, endpoint = False)
radii = 10*np.random.rand(N)
width = np.pi/4*np.random.rand(N)
colors = plt.cm.plasma(radii/10)

plt.figure(dpi = 100)
ax = plt.subplot((111), projection = 'polar')
ax.bar(theta, radii, width = width, bottom = 0, color = colors, alpha = 0.7)
plt.show()

# %%
# Line Plot on a Polar Axis 

r = np.arange(0, 2, 0.01)
theta = 2*np.pi*r

plt.figure(dpi = 100)
ax = plt.subplot(111, projection = 'polar')
ax.plot(theta, r)
ax.set_rmax(2)
ax.set_rticks([0, 0.5, 1, 1.5])
ax.set_rlabel_position(-30)
ax.grid(True)
plt.show()

# %%
# Scatter Plot on Polar Axis 

np.random.seed(0)

N = 150
r = 2*np.random.rand(N)
theta = 2*np.pi*np.random.rand(N)
area = 50*2*np.pi*r**2
colors = theta

fig = plt.figure(dpi = 100)
ax = fig.add_subplot(111, projection = 'polar')
c = ax.scatter(theta, r, c = colors, s = area, cmap = 'hsv', alpha = 0.8)
plt.show()
