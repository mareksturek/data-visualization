# %% [markdown]
# ## Iris Dataset

# %% [markdown]
# ---

# %%
# Import libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from numpy.random import randn, randint, uniform, sample
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
# Various examples

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods = 1000), columns = ['value'])
df.head()
# Out:
#                value
# 2019-06-07  0.272351
# 2019-06-08  0.316790
# 2019-06-09 -0.481350
# 2019-06-10  0.557619
# 2019-06-11 -0.022625

# %%
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))

# %%
randn(10)
# Out:
# array([-0.39517281, -0.49791387, -1.06811643,  0.65310942,  1.24044883,
#        -0.46900285,  0.62987341,  1.21219319, -0.30955427, -2.38986938])

# %%
ts.head()
# Out:
# 2019-06-07   -0.408116
# 2019-06-08   -1.376475
# 2019-06-09    0.248363
# 2019-06-10   -1.011244
# 2019-06-11   -1.159818
# Freq: D, dtype: float64

# %%
df['value'] = df['value'].cumsum()
df.head()
# Out:
#                value
# 2019-06-07  0.272351
# 2019-06-08  0.589141
# 2019-06-09  0.107791
# 2019-06-10  0.665410
# 2019-06-11  0.642785

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2019-06-07   -0.408116
# 2019-06-08   -1.784590
# 2019-06-09   -1.536228
# 2019-06-10   -2.547472
# 2019-06-11   -3.707290
# Freq: D, dtype: float64

# %%
ts.plot();

# %%
ts.plot(figsize = (10, 5));

# %%
df.plot();

# %%
# Iris dataset

iris = pd.read_csv('/Users/mareksturek/Documents/GitHub/data-visualization/data/iris.csv')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.plot(figsize = (10, 5));

# %%
iris.plot(legend = False, figsize = (10, 5), logy = True);

# %%
x = iris.drop(labels=['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length species
# 0           5.1           1.4  setosa
# 1           4.9           1.4  setosa
# 2           4.7           1.3  setosa
# 3           4.6           1.5  setosa
# 4           5.0           1.4  setosa

# %%
y = iris[['sepal_width', 'petal_width']]

# %%
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize = (16, 10), secondary_y = True, ax = ax);

# %%
df = iris.drop(['species'], axis = 1)

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind = 'bar');

# %%
df.iloc[0].plot.bar();

# %%
df.plot.bar();

# %%
df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df.head()
# Out:
#           a         b         c         d
# 0  0.391245 -0.434227 -1.475009 -0.043765
# 1 -0.324246 -0.377475  0.508943  0.806890
# 2 -1.891520  0.850788 -1.620898 -0.000938
# 3 -1.346188  0.516987 -0.489392 -0.878697
# 4 -1.299866  1.835685 -0.002582  0.261259

# %%
df.plot.bar(stacked = True);

# %%
df.plot.barh(stacked = True);

# %%
iris.plot.hist();

# %%
iris.plot(kind = 'hist');

# %%
iris.plot(kind = 'hist', bins = 50);

# %%
iris.plot(kind = 'hist', bins = 50, stacked = True);

# %%
iris.plot(kind = 'hist', bins = 30, stacked = True, orientation = 'horizontal');

# %%
iris['petal_length'].plot(kind = 'hist', bins = 50);

# %%
iris['species']
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
df = iris.drop('species', axis = 1)

# %%
df.hist(color = 'r', alpha = 0.5)
plt.show()

# %%
df.plot(kind = 'box', figsize = (10, 5));

# %%
df.plot(kind = 'box', figsize = (10, 5), vert = False);

# %%
df['sepal_length'].mean()
# Out:
# 5.843333333333335

# %%
df.plot(kind = 'area');

# %%
df.plot(kind = 'area', stacked = False, alpha = 0.2);

# %%
df.plot.scatter(x = 'sepal_width', y = 'petal_width');

# %%
df.plot.scatter(x = 'sepal_width', y = 'petal_width', c = 'sepal_length');

# %%
ax = df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'width')
df.plot.scatter(x = 'sepal_length', y = 'petal_length', ax = ax, color = 'r');

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize=10, C = 'sepal_width');

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[3].plot.pie(figsize = (5, 5));

# %%
d = df.head(3).T
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots=True, figsize = (30, 30))
plt.show()

# %%
d.plot.pie(subplots=True, figsize = (30, 30), fontsize = 24)
plt.show()

# %%
d.plot.pie(subplots=True, figsize = (30, 30), fontsize = 24, autopct = '%.2f')
plt.show()

# %%
[0.2]*4
# Out:
# [0.2, 0.2, 0.2, 0.2]

# %%
series = pd.Series([0.2]*4, index = ['a','b','c', 'd'], name = 'Pie Plot')
series.plot.pie();

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize=(8,8), diagonal = 'kde', color = 'r')
plt.show()

# %%
df.plot(subplots=True)
plt.show()

# %%
df.plot(subplots=True, sharex = False)
plt.tight_layout()
plt.show()

# %%
df.plot(subplots=True, sharex = False, layout = (2, 2), figsize = (6, 6))
plt.tight_layout()
plt.show()
